# %%
import sys, os
sys.path.append('../src')
sys.path.append('../models')

from architecture import modules
from data.datasets import BarkleyDataset
from torch.utils.data import DataLoader

import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d.axes3d import Axes3D
from mpl_toolkits.mplot3d import proj3d
from mpl_toolkits.axes_grid1 import make_axes_locatable

from tqdm import tqdm
from pyevtk.hl import gridToVTK

import matplotlib as mpl

from scipy.signal import find_peaks

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
#data = np.load('/home/roland/Projekte/Masterthesis/Reconstructing3D/data/visualization/chaotic/vis.npy')
data = np.load('/home/roland/Projekte/Masterthesis/Reconstructing3D/data/visualization/concentric/vis_conc.npy')

data.shape
# Out:
# (2048, 120, 120, 120)

# %%
pl = []

n = 100000
for x, y, z in tqdm(np.random.randint(0,120, size=(n, 3))):
    p = data[:,x,y,z]
    peaks, _ = find_peaks(p)
    for dp in np.diff(peaks):
        pl.append(dp)
# Out:
# 100%|██████████| 100000/100000 [00:05<00:00, 18060.17it/s]

# %%
np.mean(pl), np.std(pl)
# Out:
# (248.7954898263854, 88.40576721054757)

# %%
np.mean(pl), np.std(pl)
# Out:
# (197.95876096679618, 101.48541917785373)

# %%
n = 16
for x, y, z in tqdm(np.random.randint(0,120, size=(n, 3))):
    p = data[:,x,y,z]
    peaks, _ = find_peaks(p)
    plt.plot(p)
    plt.show()
# Out:
# ...
# 100%|██████████| 16/16 [00:01<00:00, 13.74it/s]

# %%
np.reshape(np.array(a), -1)
# Out:
# array([245,  96, 273, 337, 288, 224, 218, 275, 245,  96, 273, 337, 288,
#        224, 218, 275])
